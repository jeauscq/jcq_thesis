# %% [markdown]
# # Jacobian Comparison: CasADi vs PyBullet
#
# This notebook compares the Jacobian of a 2-DoF planar robot computed symbolically with CasADi vs. numerically with PyBullet.
# The goal is to ensure both implementations are consistent at arbitrary joint configurations.

# %%
# Imports
import numpy as np
import casadi as ca
import pybullet as p
import pybullet_data
import pandas as pd
from urdfpy import URDF
from math import sin, cos
import matplotlib.pyplot as plt


# === CONFIG ===
NUM_TRAJECTORIES = 50
TRAJECTORY_LEN = 498  # 498 control actions, 499 states
STATE_DIM = 4
ACTION_DIM = 2

# %%
# Load URDF and define constants (these must match the values from your system)
URDF_FILE = "../../models/2dof_planar_robot.urdf"  # Adjust path if needed
# === LOAD FILES ===
state_file = "/home/jeauscq/Desktop/jcq_thesis/datasets/Policy/MPC/unconst/mpc_generated_dataset.csv"
action_file = "/home/jeauscq/Desktop/jcq_thesis/datasets/Policy/MPC/unconst/mpc_generated_actions.csv"

robot = URDF.load(URDF_FILE)

link1 = next(link for link in robot.links if link.name == "link1")
link2 = next(link for link in robot.links if link.name == "link2")

L1 = link1.visuals[0].geometry.box.size[0]
L2 = link2.visuals[0].geometry.box.size[0]

# %%
def load_data(path, num_trajectories, expected_len):
    data = []
    with open(path, "r") as f:
        for i, line in enumerate(f):
            if i >= num_trajectories:
                break
            parts = line.strip().split(",")
            traj = [list(map(float, entry.split(";"))) for entry in parts]
            assert len(traj) == expected_len, f"Trajectory length mismatch in line {i}, obtained {len(traj)}, expected {expected_len}"
            data.append(np.array(traj))
    return np.array(data)

# %%
states = load_data(state_file, NUM_TRAJECTORIES, TRAJECTORY_LEN + 1)
actions = load_data(action_file, NUM_TRAJECTORIES, TRAJECTORY_LEN)

# %%
# Helper to compute CasADi-based force
def build_jacobian_casadi_function():
    theta1 = ca.MX.sym("theta1")
    theta2 = ca.MX.sym("theta2")

    l1 = 1.0
    l2 = 1.0
    s1 = ca.sin(theta1)
    c1 = ca.cos(theta1)
    s12 = ca.sin(theta1 + theta2)
    c12 = ca.cos(theta1 + theta2)

    J = ca.MX.zeros(2, 2)
    J[0, 0] = -l1 * s1 - l2 * s12
    J[0, 1] = -l2 * s12
    J[1, 0] = l1 * c1 + l2 * c12
    J[1, 1] = l2 * c12

    J[1, :] *= -1
    # Return both force and full Jacobian
    return ca.Function("Jac", [theta1, theta2], [J])

compute_jacobian_casadi = build_jacobian_casadi_function()

# %%
# Regular solve (no regularization)
def build_force_function_unregularized():
    J = ca.MX.sym("J", 2, 2)
    tau = ca.MX.sym("tau", 2, 1)
    F = ca.solve(J.T, tau)
    return ca.Function("F_e_unreg", [J, tau], [F])

# %%
# Regularized solve
def build_force_function_regularized(lambda_reg=1e-6):
    J = ca.MX.sym("J", 2, 2)
    tau = ca.MX.sym("tau", 2, 1)
    JTJ = J.T @ J
    F = ca.solve(JTJ + lambda_reg * ca.MX.eye(JTJ.size1()), J.T @ tau)
    return ca.Function("F_e_reg", [J, tau], [F])

# %%
# Instantiate both
casadi_force_fn_unreg = build_force_function_unregularized()
casadi_force_fn_reg = build_force_function_regularized()

# %%
# PyBullet setup
client = p.connect(p.DIRECT)
p.setAdditionalSearchPath(pybullet_data.getDataPath())
p.setGravity(0, 0, -9.81)

robot_id = p.loadURDF(URDF_FILE, basePosition=(0, 0, 0.07),
                      baseOrientation=p.getQuaternionFromEuler((0, 3.14, 0)),
                      useFixedBase=True)

# Identify joint indices
joint_indices = [i for i in range(p.getNumJoints(robot_id)) if p.getJointInfo(robot_id, i)[2] == p.JOINT_REVOLUTE]

# %%
# Helper to compute PyBullet-based end-effector force
def compute_force_pybullet(theta1, theta2, dtheta1, dtheta2, torque):
    p.resetJointState(robot_id, 0, theta1, dtheta1)
    p.resetJointState(robot_id, 1, theta2, dtheta2)
    zero_acc = [0, 0]
    jac_t, _ = p.calculateJacobian(robot_id, linkIndex=2, localPosition=[1, 0, 0], objPositions=[theta1, theta2], objVelocities=[dtheta1, dtheta2], objAccelerations=zero_acc)
    J = np.array(jac_t)[[0, 2], :]  # Only translational part

    J_pinv = np.linalg.pinv(J)

    return J_pinv.T @ torque, J  # Force from torque = (J^T)^+ * tau

# %%
def build_force_function_regularized_adaptive():
    J = ca.MX.sym("J", 2, 2)
    tau = ca.MX.sym("tau", 2, 1)
    lambda_reg = ca.MX.sym("lambda_reg")  # Now a runtime input
    JTJ = J.T @ J
    F = ca.solve(JTJ + lambda_reg * ca.MX.eye(JTJ.size1()), J.T @ tau)
    return ca.Function("F_e_reg_adaptive", [J, tau, lambda_reg], [F])

casadi_force_fn_reg_adaptive = build_force_function_regularized_adaptive()

# %%
# Compare forces and Jacobians
pyb_forces = []

for traj_idx in range(2):
    for step in range(498):
        state = states[traj_idx, step]
        torque = actions[traj_idx, step]
        theta1, theta2 = state[0], state[1]
        dtheta1, dtheta2 = state[2], state[3]

        F_pybullet, J_pybullet = compute_force_pybullet(theta1, theta2, dtheta1, dtheta2, torque)
        F_pybullet = np.linalg.norm(F_pybullet)

        # Get symbolic Jacobian from CasADi
        J_casadi = compute_jacobian_casadi(theta1, theta2)  # assumed to return np.array
        cond = np.linalg.cond(J_casadi)
        lambda_reg = min(1.0, 1e-4 * cond**2)
        F_casadi = casadi_force_fn_reg_adaptive(J_casadi_mx, tau_mx, ca.DM(lambda_reg))


        # Choose function based on condition number
        J_casadi_mx = ca.DM(J_casadi)
        tau_mx = ca.DM(torque).reshape((2, 1))
        if cond < 0.01:
            print(f"Condition number too low: {cond:.5f} in traj {traj_idx} and step {step}")
            F_casadi = casadi_force_fn_reg(J_casadi_mx, tau_mx)
        if cond > 100:
            print(f"Condition number too high: {cond:.5f} in traj {traj_idx} and step {step}")
            F_casadi = casadi_force_fn_reg(J_casadi_mx, tau_mx)
        else:
            F_casadi = casadi_force_fn_unreg(J_casadi_mx, tau_mx)

        F_casadi = F_casadi.full().flatten()
        F_casadi = np.linalg.norm(F_casadi)

        pyb_forces.append(F_pybullet)

        if F_casadi > 100:
            print(f"Force too high: {F_casadi:.5f} in traj {traj_idx} and step {step}")
            print(f"PyBullet force: {F_pybullet:.5f}, CasADi force: {F_casadi:.5f}")


        if abs(F_pybullet - F_casadi) > 0.01:
            print(f"Concerning difference of {F_pybullet-F_casadi:.5f} in traj {traj_idx} and step {step}")
            print(f"PyBullet force: {F_pybullet:.5f}, CasADi force: {F_casadi:.5f}")
    print(f"Finished trajectory {traj_idx}.")
# Out:
# Force too high: 121.56720 in traj 0 and step 177
# PyBullet force: 121.56720, CasADi force: 121.56720
# Force too high: 124.25063 in traj 0 and step 197
# PyBullet force: 124.25063, CasADi force: 124.25063
# Force too high: 100.93910 in traj 0 and step 427
# PyBullet force: 100.93910, CasADi force: 100.93910
# Force too high: 105.47537 in traj 0 and step 428
# PyBullet force: 105.47537, CasADi force: 105.47537
# Force too high: 110.57035 in traj 0 and step 429
# PyBullet force: 110.57035, CasADi force: 110.57035
# Force too high: 116.32484 in traj 0 and step 430
# PyBullet force: 116.32484, CasADi force: 116.32484
# Force too high: 122.86252 in traj 0 and step 431
# PyBullet force: 122.86252, CasADi force: 122.86252
# Force too high: 130.34575 in traj 0 and step 432
# PyBullet force: 130.34575, CasADi force: 130.34575
# Force too high: 138.98145 in traj 0 and step 433
# PyBullet force: 138.98145, CasADi force: 138.98145
# Force too high: 149.04592 in traj 0 and step 434
# PyBullet force: 149.04592, CasADi force: 149.04592
# Condition number too high: 107.97438 in traj 0 and step 435
# Force too high: 472.29621 in traj 0 and step 435
# PyBullet force: 160.91281, CasADi force: 472.29621
# Concerning difference of -311.38339 in traj 0 and step 435
# PyBullet force: 160.91281, CasADi force: 472.29621
# Condition number too high: 118.36413 in traj 0 and step 436
# Force too high: 516.31549 in traj 0 and step 436
# PyBullet force: 175.10020, CasADi force: 516.31549
# Concerning difference of -341.21529 in traj 0 and step 436
# PyBullet force: 175.10020, CasADi force: 516.31549
# Condition number too high: 130.96520 in traj 0 and step 437
# Force too high: 569.76457 in traj 0 and step 437
# PyBullet force: 192.34229, CasADi force: 569.76457
# Concerning difference of -377.42228 in traj 0 and step 437
# PyBullet force: 192.34229, CasADi force: 569.76457
# Condition number too high: 146.57207 in traj 0 and step 438
# Force too high: 616.68463 in traj 0 and step 438
# PyBullet force: 210.25034, CasADi force: 616.68463
# Concerning difference of -406.43428 in traj 0 and step 438
# PyBullet force: 210.25034, CasADi force: 616.68463
# Condition number too high: 166.40049 in traj 0 and step 439
# Force too high: 677.83411 in traj 0 and step 439
# PyBullet force: 233.37050, CasADi force: 677.83411
# Concerning difference of -444.46360 in traj 0 and step 439
# PyBullet force: 233.37050, CasADi force: 677.83411
# Condition number too high: 192.43139 in traj 0 and step 440
# Force too high: 759.16585 in traj 0 and step 440
# PyBullet force: 264.02545, CasADi force: 759.16585
# Concerning difference of -495.14040 in traj 0 and step 440
# PyBullet force: 264.02545, CasADi force: 759.16585
# Condition number too high: 228.08375 in traj 0 and step 441
# Force too high: 870.80894 in traj 0 and step 441
# PyBullet force: 306.25467, CasADi force: 870.80894
# Concerning difference of -564.55427 in traj 0 and step 441
# PyBullet force: 306.25467, CasADi force: 870.80894
# Condition number too high: 279.93298 in traj 0 and step 442
# Force too high: 1031.77763 in traj 0 and step 442
# PyBullet force: 367.84906, CasADi force: 1031.77763
# Concerning difference of -663.92857 in traj 0 and step 442
# PyBullet force: 367.84906, CasADi force: 1031.77763
# Condition number too high: 362.18255 in traj 0 and step 443
# Force too high: 1281.03470 in traj 0 and step 443
# PyBullet force: 465.65269, CasADi force: 1281.03470
# Concerning difference of -815.38202 in traj 0 and step 443
# PyBullet force: 465.65269, CasADi force: 1281.03470
# Condition number too high: 512.65919 in traj 0 and step 444
# Force too high: 1711.80698 in traj 0 and step 444
# PyBullet force: 644.76494, CasADi force: 1711.80698
# Concerning difference of -1067.04204 in traj 0 and step 444
# PyBullet force: 644.76494, CasADi force: 1711.80698
# Condition number too high: 876.26850 in traj 0 and step 445
# Force too high: 2582.94027 in traj 0 and step 445
# PyBullet force: 1080.90387, CasADi force: 2582.94027
# Concerning difference of -1502.03640 in traj 0 and step 445
# PyBullet force: 1080.90387, CasADi force: 2582.94027
# Condition number too high: 3003.00239 in traj 0 and step 446
# Force too high: 3556.79988 in traj 0 and step 446
# PyBullet force: 3732.43446, CasADi force: 3556.79988
# Concerning difference of 175.63459 in traj 0 and step 446
# PyBullet force: 3732.43446, CasADi force: 3556.79988
# Condition number too high: 2113.27048 in traj 0 and step 447
# Force too high: 3965.78101 in traj 0 and step 447
# PyBullet force: 3211.43060, CasADi force: 3965.78101
# Concerning difference of -754.35041 in traj 0 and step 447
# PyBullet force: 3211.43060, CasADi force: 3965.78101
# Condition number too high: 786.16119 in traj 0 and step 448
# Force too high: 2301.01179 in traj 0 and step 448
# PyBullet force: 960.45692, CasADi force: 2301.01179
# Concerning difference of -1340.55487 in traj 0 and step 448
# PyBullet force: 960.45692, CasADi force: 2301.01179
# Condition number too high: 484.63322 in traj 0 and step 449
# Force too high: 1544.20944 in traj 0 and step 449
# PyBullet force: 577.14530, CasADi force: 1544.20944
# Concerning difference of -967.06414 in traj 0 and step 449
# PyBullet force: 577.14530, CasADi force: 1544.20944
# Condition number too high: 350.52758 in traj 0 and step 450
# Force too high: 1168.71104 in traj 0 and step 450
# PyBullet force: 418.22050, CasADi force: 1168.71104
# Concerning difference of -750.49054 in traj 0 and step 450
# PyBullet force: 418.22050, CasADi force: 1168.71104
# Condition number too high: 274.65823 in traj 0 and step 451
# Force too high: 945.31305 in traj 0 and step 451
# PyBullet force: 329.16241, CasADi force: 945.31305
# Concerning difference of -616.15064 in traj 0 and step 451
# PyBullet force: 329.16241, CasADi force: 945.31305
# Condition number too high: 225.83767 in traj 0 and step 452
# Force too high: 796.97478 in traj 0 and step 452
# PyBullet force: 271.71301, CasADi force: 796.97478
# Concerning difference of -525.26178 in traj 0 and step 452
# PyBullet force: 271.71301, CasADi force: 796.97478
# Condition number too high: 191.79649 in traj 0 and step 453
# Force too high: 691.11599 in traj 0 and step 453
# PyBullet force: 231.46199, CasADi force: 691.11599
# Concerning difference of -459.65401 in traj 0 and step 453
# PyBullet force: 231.46199, CasADi force: 691.11599
# Condition number too high: 166.69457 in traj 0 and step 454
# Force too high: 611.53390 in traj 0 and step 454
# PyBullet force: 201.61965, CasADi force: 611.53390
# Concerning difference of -409.91425 in traj 0 and step 454
# PyBullet force: 201.61965, CasADi force: 611.53390
# Condition number too high: 147.42365 in traj 0 and step 455
# Force too high: 549.37837 in traj 0 and step 455
# PyBullet force: 178.57974, CasADi force: 549.37837
# Concerning difference of -370.79863 in traj 0 and step 455
# PyBullet force: 178.57974, CasADi force: 549.37837
# Condition number too high: 132.15636 in traj 0 and step 456
# Force too high: 499.34173 in traj 0 and step 456
# PyBullet force: 160.22144, CasADi force: 499.34173
# Concerning difference of -339.12030 in traj 0 and step 456
# PyBullet force: 160.22144, CasADi force: 499.34173
# Condition number too high: 119.76526 in traj 0 and step 457
# Force too high: 458.11452 in traj 0 and step 457
# PyBullet force: 145.23592, CasADi force: 458.11452
# Concerning difference of -312.87860 in traj 0 and step 457
# PyBullet force: 145.23592, CasADi force: 458.11452
# Condition number too high: 109.50269 in traj 0 and step 458
# Force too high: 423.47276 in traj 0 and step 458
# PyBullet force: 132.75400, CasADi force: 423.47276
# Concerning difference of -290.71876 in traj 0 and step 458
# PyBullet force: 132.75400, CasADi force: 423.47276
# Condition number too high: 100.86760 in traj 0 and step 459
# Force too high: 393.92042 in traj 0 and step 459
# PyBullet force: 122.19315, CasADi force: 393.92042
# Concerning difference of -271.72728 in traj 0 and step 459
# PyBullet force: 122.19315, CasADi force: 393.92042
# Force too high: 113.13111 in traj 0 and step 460
# PyBullet force: 113.13111, CasADi force: 113.13111
# Force too high: 105.26745 in traj 0 and step 461
# PyBullet force: 105.26745, CasADi force: 105.26745
# Finished trajectory 0.
# Condition number too high: 139.03406 in traj 1 and step 0
# Force too high: 467.91187 in traj 1 and step 0
# PyBullet force: 113.56732, CasADi force: 467.91187
# Concerning difference of -354.34455 in traj 1 and step 0
# PyBullet force: 113.56732, CasADi force: 467.91187
# Condition number too high: 116.90783 in traj 1 and step 1
# Force too high: 435.23799 in traj 1 and step 1
# PyBullet force: 97.43139, CasADi force: 435.23799
# Concerning difference of -337.80660 in traj 1 and step 1
# PyBullet force: 97.43139, CasADi force: 435.23799
# Condition number too high: 100.87371 in traj 1 and step 2
# Force too high: 408.32304 in traj 1 and step 2
# PyBullet force: 84.90596, CasADi force: 408.32304
# Concerning difference of -323.41708 in traj 1 and step 2
# PyBullet force: 84.90596, CasADi force: 408.32304
# Force too high: 117.45122 in traj 1 and step 419
# PyBullet force: 117.45122, CasADi force: 117.45122
# Force too high: 245.14949 in traj 1 and step 420
# PyBullet force: 245.14949, CasADi force: 245.14949
# Force too high: 121.79690 in traj 1 and step 421
# PyBullet force: 121.79690, CasADi force: 121.79690
# Force too high: 229.66939 in traj 1 and step 442
# PyBullet force: 229.66939, CasADi force: 229.66939
# Force too high: 562.02776 in traj 1 and step 443
# PyBullet force: 562.02776, CasADi force: 562.02776
# Force too high: 1308.87045 in traj 1 and step 444
# PyBullet force: 1308.87045, CasADi force: 1308.87045
# Force too high: 591.61165 in traj 1 and step 445
# PyBullet force: 591.61165, CasADi force: 591.61165
# Force too high: 253.70888 in traj 1 and step 446
# PyBullet force: 253.70888, CasADi force: 253.70888
# Force too high: 100.23138 in traj 1 and step 447
# PyBullet force: 100.23138, CasADi force: 100.23138
# Finished trajectory 1.
